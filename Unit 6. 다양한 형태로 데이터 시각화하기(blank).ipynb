# %% [markdown]
# # 1. 다양한 형태의 데이터 표현
# ## 1) 여러 종류의 데이터 표현
# ### (1) plot 함수

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (5,3), dpi = 300) # 그래프 크기 및 해상도 조절

plt.rc('font',family='Malgun Gothic') # 한글 폰트설정
plt.plot([1, 2, 3, 4], label = 'type A')
plt.plot([4, 3, 2, 1], label = 'type B')

plt.title('제목') # 제목 넣기

plt.xlim(0,3) # x축 값 범위
plt.ylim(1,4) # y축 값 범위

plt.xticks(range(4),['가','나','다','라']) # x축 내용
plt.yticks(range(5)) # y축 내용

plt.xlabel('x축') # x축 레이블
plt.ylabel('y축') # y축 레이블

plt.legend() # 범례
plt.savefig('data.png') # 파일 저장

plt.show() # 그래프 보여주기

# %%
plt.plot([1,2,3,4], [1,4,2,5], 'r^', [0,2,5,6], [1,2,3,6], 'g-')  # 값을 바꿔보세요!
plt.show()

# %% [markdown]
# ### (2) subplot 함수

# %%
plt.subplot(_,_,1)
plt.plot(range(100,10000), '_')  # 값을 바꿔보세요!

plt.subplot(_,_,2)
plt.plot(range(100,1,-1), '_')
plt.show()

# %%
a = plt.figure(dpi=300)
plt.subplot(_,_,1)
plt.plot(range(100,10000), 'g')  # 값을 바꿔보세요!

plt.subplot(_,_,2)
plt.plot(range(100,1,-1), 'r')
plt.show()

# %% [markdown]
# ## 2) 막대그래프

# %%
import matplotlib.pyplot as plt

plt.___([1,2,3,4],[10,20,30,40]) # 값을 바꿔보세요!
plt.show()

# %%
burger = [6, 10, 8]  # 값을 바꿔보세요!

plt.bar(______, ______, width = ___)
plt.show()

# %%
brand = ['A-Burger','C-Burger','G-Burger']
burger = [6, 10, 8]

plt.bar(range(3), burger, width = 0.4)
plt.xticks(______, _____)
plt.show()

# %%
brand = ['A-Burger','C-Burger','G-Burger']
burger = [6, 10, 8]
pizza = [14, 20, 19]

plt.bar(range(3), burger, width = 0.4, label='햄버거가격')
plt.bar([_______], pizza, width = 0.4, label='피자가격')
plt.legend()
plt.xticks(________], brand)
# plt.xticks([0,1,2], brand)
plt.show()

# %%
brand = ['A-Burger','C-Burger','G-Burger']
burger = [6, 10, 8]

plt._____(range(3), burger, height = 0.4)
plt._____(range(3), brand)
plt.show()

# %% [markdown]
# ## 3) 히스토그램

# %%
import matplotlib.pyplot as plt

plt.____([1,1,2,4,5,7,8,9], bins = __)
plt.show()

# %%
plt.____([1,1,2,4,5,7,8,9], bins = ___)
plt.show()

# %%
import random
result = []

for i in range(100):
    result.append(______________)
    
plt.title('주사위 시뮬레이션 결과(100번)')
plt.hist(_____, bins = __, color='g')
plt.show()

# %%
result = []

for i in range(_________):
    result.append(random.randint(1,6))
    
plt.title('주사위 시뮬레이션 결과(1,000,000번)')
plt.hist(result, bins = 6, color='g')
plt.show()

# %% [markdown]
# ## 4) 상자 수염 그림

# %%
import matplotlib.pyplot as plt
import random

x = []
y = []
z = []

for i in range(100):
    x.append(random.randint(1,100))
    y.append(random.randint(1,100))
    z.append(random.randint(1,100))
    
plt.figure(dpi=300)
plt.title('평가 결과 분석')
plt._______(_______,labels = ['1반','2반','3반'])
plt.show()

# %% [markdown]
# ## 5) 산포도 및 버블 차트

# %%
import matplotlib.pyplot as plt

plt.______([1,2,3,2],[2,3,3,1])
plt.show()

# %%
import matplotlib.pyplot as plt
import random
x = []
y = []

plt.title('랜덤 좌표')

for i in range(100):
    x.append(random.randint(1,10000))
    y.append(random.randint(1,10000))
    
plt.scatter(__,__)
plt.show()

# %%
import matplotlib.pyplot as plt
import random
x = []
y = []
z = []

plt.title('랜덤 좌표, 랜덤 사이즈')

for i in range(100):
    x.append(random.randint(1,10000))
    y.append(random.randint(1,10000))
    z.append(random.randint(1,1000))  # 값을 바꿔보세요!
    
plt.axis([-1000, 11000, -1000, 11000])
plt.scatter(x, y, s = __, c = ['r','g','m','c'], alpha = ____)  # 값을 바꿔보세요!
plt.show()

# %% [markdown]
# ## 6) 원 그래프

# %%
import matplotlib.pyplot as plt

size = [15, 20, 25, 40]  # 값을 바꿔보세요!

plt.___(size)
plt.show()

# %%
import matplotlib.pyplot as plt

size = [13, 2, 14, 7]

plt.pie(size)
plt.axis(______)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6,4), dpi=300)

size = [231, 132, 94, 341]  # 값을 바꿔보세요!
explode = (0, 0, 0, 0.1)  # 값을 바꿔보세요!
labels = '기린', '고양이', '토끼', '강아지'
colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral']  # 값을 바꿔보세요!

plt.title('좋아하는 동물 투표 결과')
plt.pie(size, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)

plt.axis('equal')
plt.show()

# %%
plt.rcParams['axes.unicode_minus'] = False
plt.plot(range(-100,100))
plt.show()
