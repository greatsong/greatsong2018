# %% [markdown]
# ## 1. plot 함수의 이해
# ### 1) 기본 그래프 그리기

# %%
import _______________ as ___

plt.____(_________)
plt.____()

# %%
import matplotlib.pyplot as plt

plt.plot(_______, __________)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot(________, ___________)
plt.show()

# %% [markdown]
# ### 2) 그래프 꾸미기
# #### 1) 색과 마커 형태 설정하기

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], ___)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], ____)
plt.show()

# %% [markdown]
# #### 2) 한글 표현하기

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], 'g^')
plt._____('기본 그래프')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.__(______, family=_____________)

plt.plot([1, 2, 3, 4])
plt.title('제목')
plt.show()

# %% [markdown]
# #### 3) x, y 축 꾸미기

# %%
import matplotlib.pyplot as plt
plt.rc('font', family='Malgun Gothic')

plt.plot([1, 2, 3, 4])
plt.title('제목')

plt._____('x축')
plt._____('y축')

plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4])
plt.____(0,3) # 숫자를 바꿔보세요!
plt.____(1,4) # 숫자를 바꿔보세요!
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4])
plt.______([0, 1, 2, 3])  # 숫자를 바꿔보세요!
plt.______(range(1, 5))  # 숫자를 바꿔보세요!
plt.show()

# %% [markdown]
# ### 3) 그래프 한 번에 그리기

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], label = _______ ) # 글자를 바꿔보세요!
plt.plot([4, 3, 2, 1], label = _______ ) # 글자를 바꿔보세요!

plt.legend(loc=__)  # 0~10까지 숫자를 바꿔보세요!
plt.show()

# %% [markdown]
# ### 4) 파일로 저장하기

# %%
import matplotlib.pyplot as plt
plt.______(_______ = (10,4), ___ = 300)  # 숫자를 바꿔보세요!
# dpi : dots per inch의 약자
plt.plot([1, 2, 3, 4], label = 'type A')
plt.plot([4, 3, 2, 1], label = 'type B')
plt.legend()
plt._______('data.png') # 이름을 바꿔보고 탐색기로 열어보세요!
plt.show()

# %%
fig = plt.figure()
fig.canvas.get_supported_filetypes()
# Out:
# {'eps': 'Encapsulated Postscript',
#  'jpeg': 'Joint Photographic Experts Group',
#  'jpg': 'Joint Photographic Experts Group',
#  'pdf': 'Portable Document Format',
#  'pgf': 'PGF code for LaTeX',
#  'png': 'Portable Network Graphics',
#  'ps': 'Postscript',
#  'raw': 'Raw RGBA bitmap',
#  'rgba': 'Raw RGBA bitmap',
#  'svg': 'Scalable Vector Graphics',
#  'svgz': 'Scalable Vector Graphics',
#  'tif': 'Tagged Image File Format',
#  'tiff': 'Tagged Image File Format'}

# %% [markdown]
# ## [ 자유롭게 그래프를 표현해보세요!^^ ]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (5,3), dpi = 300) # 그래프 크기 및 해상도 조절

plt.rc('font',family='Malgun Gothic') # 한글 폰트설정
plt.plot([1, 2, 3, 4], label = 'type A')
plt.plot([4, 3, 2, 1], label = 'type B')

plt.title('제목') # 제목 넣기

plt.xlim(0,3) # x축 값 범위
plt.ylim(1,4) # y축 값 범위

plt.xticks(range(4),['가','나','다','라']) # x축 내용
plt.yticks(range(5)) # y축 내용

plt.xlabel('x축') # x축 레이블
plt.ylabel('y축') # y축 레이블

plt.legend() # 범례
plt.savefig('data.png') # 파일 저장

plt.show() # 그래프 보여주기
